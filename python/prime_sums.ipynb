# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


import matplotlib as mpl
default_dpi = mpl.rcParamsDefault['figure.dpi']
mpl.rcParams['figure.dpi'] = default_dpi*1.5

with open('../primes_from_10^6_to_10^7') as f:
    primes = f.readlines()
primes = [int(p) for p in primes if p]

sums = []
for i in primes:
    summ = sum([int(s) for s in str(i)])
    sums.append(summ)
print(sums[:10])
plt.scatter(*zip(*enumerate(sums)), s=0.01)    

# list the gaps
print(sorted(set([i for i in range(2,max(sums)+1)]) - set(sums)))
# Out:
# [4, 7, 11, 13, 10, 19, 10, 5, 8, 8]
# [2, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60]
